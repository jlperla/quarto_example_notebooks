# %% [markdown]
# # Course Overview
#
# Example Quarto Course
#
# Jesse Perla (University of British Columbia)
#
# # Course Overview and Objectives
#
# ## Using Packages
#
# -   First ensure your project is activated and packages instantiated

# %%
using LinearAlgebra, Statistics, Plots

# %% [markdown]
# ## Plotting Random Numbers

# %%
n = 20
ep = randn(n)
plot(1:n, ep;size=(600,400))
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## Example: Recessions Transitions
#
# <figure class=''>
#
# ![](attachment:intro_files/figure-ipynb/dot-figure-1.png)
#
# </figure>
#
# -   Transitions empirically estimated in [Hamilton
#     2005](https://julia.quantecon.org/zreferences.html#id84) $$
#     P \equiv \begin{bmatrix}
#        0.971 & 0.029 & 0 \\
#        0.145 & 0.778 & 0.077 \\
#        0 & 0.508 & 0.492
#     \end{bmatrix}
#     $$
