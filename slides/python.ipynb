# %% [markdown]
# # Python Slides
#
# Example Quarto Course
#
# Jesse Perla (University of British Columbia)
#
# # Python Section
#
# ## Some code

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
from matplotlib.animation import FuncAnimation
import IPython.display
print(f"machine epsilon for float64 = {np.finfo(float).eps}")
# Out:
# machine epsilon for float64 = 2.220446049250313e-16

# %% [markdown]
# ## Code

# %%
fig, ax = plt.subplots()
T = 20
ax.plot(range(T+1),np.random.randn(T+1))
plt.show()

# %% [markdown]
# ## CLT of Exponential to $N=100$

# %%
distribution = scipy.stats.expon(1/0.5)
mu, s = distribution.mean(), distribution.std()
fig, ax = plt.subplots()
def update(n):
    ax.clear()
    data = distribution.rvs((5000, n))
    sample_means = data.mean(axis=1)
    Y = np.sqrt(n) * (sample_means - mu)
    ax.set_xlim(-3 * s, 3 * s)
    ax.set_ylim(0, 0.5)
    ax.hist(Y, bins=60, alpha=0.5,
      density=True)
    ax.set_title(f"CLT for $N = {n}$")
ani = FuncAnimation(fig,update,
  frames=range(1, 100, 5),
  interval=500,blit=False, repeat=False)
plt.close()
IPython.display.HTML(ani.to_html5_video())
# Out:
# <video width="672" height="480" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## Including a File
#
# -   Linking to a [file](../scripts/example.py). Not executed below

# %%
import jsonargparse
def example(M: int = 2,
    sigma: float = 0.0001):
    print(M * sigma)

if __name__ == "__main__":
    jsonargparse.CLI(example)
